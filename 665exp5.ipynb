# %% [markdown]
# <a href="https://colab.research.google.com/github/Vikas-g11/NLP-LAB/blob/main/665exp5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install spacy nltk

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 95.3 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy
import nltk
from nltk.stem import PorterStemmer

# %%
nlp = spacy.load("en_core_web_sm")

# %%
text = "HE and SHE are the good frinds may be.."
doc = nlp(text)

# %%
[token.text for token in doc]
# Out:
# ['HE', 'and', 'SHE', 'are', 'the', 'good', 'frinds', 'may', 'be', '..']

# %%
[token.text for token in doc if not token.is_stop]
# Out:
# ['good', 'frinds', '..']

# %%
[token.lemma_ for token in doc]
# Out:
# ['he', 'and', 'she', 'be', 'the', 'good', 'frind', 'may', 'be', '..']

# %%
[(token.text, token.pos_) for token in doc]
# Out:
# [('HE', 'PRON'),
#  ('and', 'CCONJ'),
#  ('SHE', 'PRON'),
#  ('are', 'AUX'),
#  ('the', 'DET'),
#  ('good', 'ADJ'),
#  ('frinds', 'NOUN'),
#  ('may', 'AUX'),
#  ('be', 'AUX'),
#  ('..', 'PUNCT')]

# %%
[(ent.text, ent.label_) for ent in doc.ents]
# Out:
# [('SHE', 'ORG')]
