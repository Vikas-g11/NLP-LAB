# %% [markdown]
# <a href="https://colab.research.google.com/github/Vikas-g11/NLP-LAB/blob/main/665exp7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
import re
from nltk.tokenize import word_tokenize
from collections import Counter
import matplotlib.pyplot as plt

# %%
speech = """
I have a dream that one day this nation will rise up and live out the true meaning of its creed:
We hold these truths to be self-evident, that all men are created equal.

I have a dream that one day on the red hills of Georgia,
the sons of former slaves and the sons of former slave owners
will be able to sit down together at the table of brotherhood.

I have a dream that my four little children will one day live in a nation
where they will not be judged by the color of their skin
but by the content of their character.
"""

print(speech)
# Out:
# I have a dream that one day this nation will rise up and live out the true meaning of its creed:
# We hold these truths to be self-evident, that all men are created equal.
#
# I have a dream that one day on the red hills of Georgia,
# the sons of former slaves and the sons of former slave owners
# will be able to sit down together at the table of brotherhood.
#
# I have a dream that my four little children will one day live in a nation
# where they will not be judged by the color of their skin
# but by the content of their character.

# %%
speech = speech.lower()
print(speech)
#onvert Text to Lowercase
# Out:
# i have a dream that one day this nation will rise up and live out the true meaning of its creed we hold these truths to be selfevident that all men are created equal i have a dream that one day on the red hills of georgia the sons of former slaves and the sons of former slave owners will be able to sit down together at the table of brotherhood i have a dream that my four little children will one day live in a nation where they will not be judged by the color of their skin but by the content of their character

# %%
speech = re.sub(r'[^a-z\s]', '', speech)
print(speech)
#removal of non-word charector
# Out:
# i have a dream that one day this nation will rise up and live out the true meaning of its creed
# we hold these truths to be selfevident that all men are created equal
#
# i have a dream that one day on the red hills of georgia
# the sons of former slaves and the sons of former slave owners
# will be able to sit down together at the table of brotherhood
#
# i have a dream that my four little children will one day live in a nation
# where they will not be judged by the color of their skin
# but by the content of their character

# %%
nltk.download('punkt_tab')
speech = re.sub(r'\s+', ' ', speech).strip()
print(speech)
# Out:
# i have a dream that one day this nation will rise up and live out the true meaning of its creed we hold these truths to be selfevident that all men are created equal i have a dream that one day on the red hills of georgia the sons of former slaves and the sons of former slave owners will be able to sit down together at the table of brotherhood i have a dream that my four little children will one day live in a nation where they will not be judged by the color of their skin but by the content of their character

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
import re
from nltk.tokenize import word_tokenize

# %%
tokens = word_tokenize(speech)
print(tokens)
# Out:
# ['I', 'have', 'a', 'dream', 'that', 'one', 'day', 'this', 'nation', 'will', 'rise', 'up', 'and', 'live', 'out', 'the', 'true', 'meaning', 'of', 'its', 'creed', ':', 'We', 'hold', 'these', 'truths', 'to', 'be', 'self-evident', ',', 'that', 'all', 'men', 'are', 'created', 'equal', '.', 'I', 'have', 'a', 'dream', 'that', 'one', 'day', 'on', 'the', 'red', 'hills', 'of', 'Georgia', ',', 'the', 'sons', 'of', 'former', 'slaves', 'and', 'the', 'sons', 'of', 'former', 'slave', 'owners', 'will', 'be', 'able', 'to', 'sit', 'down', 'together', 'at', 'the', 'table', 'of', 'brotherhood', '.', 'I', 'have', 'a', 'dream', 'that', 'my', 'four', 'little', 'children', 'will', 'one', 'day', 'live', 'in', 'a', 'nation', 'where', 'they', 'will', 'not', 'be', 'judged', 'by', 'the', 'color', 'of', 'their', 'skin', 'but', 'by', 'the', 'content', 'of', 'their', 'character', '.']

# %%
word_freq = Counter(tokens)
print(word_freq)
# Out:
# Counter({'the': 7, 'of': 7, 'a': 4, 'that': 4, 'will': 4, 'I': 3, 'have': 3, 'dream': 3, 'one': 3, 'day': 3, 'be': 3, '.': 3, 'nation': 2, 'and': 2, 'live': 2, 'to': 2, ',': 2, 'sons': 2, 'former': 2, 'by': 2, 'their': 2, 'this': 1, 'rise': 1, 'up': 1, 'out': 1, 'true': 1, 'meaning': 1, 'its': 1, 'creed': 1, ':': 1, 'We': 1, 'hold': 1, 'these': 1, 'truths': 1, 'self-evident': 1, 'all': 1, 'men': 1, 'are': 1, 'created': 1, 'equal': 1, 'on': 1, 'red': 1, 'hills': 1, 'Georgia': 1, 'slaves': 1, 'slave': 1, 'owners': 1, 'able': 1, 'sit': 1, 'down': 1, 'together': 1, 'at': 1, 'table': 1, 'brotherhood': 1, 'my': 1, 'four': 1, 'little': 1, 'children': 1, 'in': 1, 'where': 1, 'they': 1, 'not': 1, 'judged': 1, 'color': 1, 'skin': 1, 'but': 1, 'content': 1, 'character': 1})

# %%
top_50 = word_freq.most_common(50)

print("Top 50 Frequent Words:\n")
for word, freq in top_50:
    print(word, ":", freq)
# Out:
# Top 50 Frequent Words:
#
# the : 7
# of : 7
# a : 4
# that : 4
# will : 4
# I : 3
# have : 3
# dream : 3
# one : 3
# day : 3
# be : 3
# . : 3
# nation : 2
# and : 2
# live : 2
# to : 2
# , : 2
# sons : 2
# former : 2
# by : 2
# their : 2
# this : 1
# rise : 1
# up : 1
# out : 1
# true : 1
# meaning : 1
# its : 1
# creed : 1
# : : 1
# We : 1
# hold : 1
# these : 1
# truths : 1
# self-evident : 1
# all : 1
# men : 1
# are : 1
# created : 1
# equal : 1
# on : 1
# red : 1
# hills : 1
# Georgia : 1
# slaves : 1
# slave : 1
# owners : 1
# able : 1
# sit : 1
# down : 1
